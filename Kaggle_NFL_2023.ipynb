# %% [markdown]
# <a href="https://colab.research.google.com/github/stevenhastings/NFL_openCV/blob/main/Kaggle_NFL_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# # ***GAMES***
# ### Schema:
# * gameId: Game identifier, unique (numeric)
# * season: Season of game (numeric)
# * week: Week of game (numeric)
# * gameDate: Game Date (time, mm/dd/yyyy)
# * gameTimeEastern: Start time of game (time, HH:MM:SS, EST)
# * homeTeamAbbr: Home team three-letter code (text)
# * visitorTeamAbbr: Visiting team three-letter code (text)

# %%
games = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/games.csv")

# %%
print(games.info())

games.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   gameId           122 non-null    int64
#  1   season           122 non-null    int64
#  2   week             122 non-null    int64
#  3   gameDate         122 non-null    object
#  4   gameTimeEastern  122 non-null    object
#  5   homeTeamAbbr     122 non-null    object
#  6   visitorTeamAbbr  122 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 6.8+ KB
# None
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0  2021090900    2021     1  09/09/2021        20:20:00           TB
# 1  2021091200    2021     1  09/12/2021        13:00:00          ATL
# 2  2021091201    2021     1  09/12/2021        13:00:00          BUF
# 3  2021091202    2021     1  09/12/2021        13:00:00          CAR
# ...

# %% [markdown]
# Get all game IDs for each team

# %%
# games[games['visitorTeamAbbr'] == 'JAX']['gameId'].values

# %%
BrownsGameIds = [2021091209, 2021100305, 2021101009, 2021091902, 2021092601, 2021101708, 2021102100, 2021103103]
PatriotsGameIds = [2021091210, 2021092605, 2021100313, 2021101710, 2021102403, 2021091906, 2021101003, 2021103108]
BuccaneersGameIds = [2021092611, 2021100313, 2021101400, 2021103111, 2021090900, 2021091910, 2021101007, 2021102409]
RamsGameIds = [2021091213, 2021092611, 2021100309, 2021102406, 2021091903, 2021100700, 2021101706, 2021103105]
VikingsGameIds = [2021091203, 2021091909, 2021101702, 2021092612, 2021100305, 2021101005, 2021103112]
BroncosGameIds = [2021092609, 2021100311, 2021101709, 2021103110, 2021091212, 2021091904, 2021101006, 2021102100]
RavensGameIds = [2021091300, 2021092602, 2021100311, 2021091913, 2021101100, 2021101701, 2021102400]
SeahawksGameIds = [2021091912, 2021100700, 2021102500, 2021103109, 2021091206, 2021092612, 2021100310, 2021101711]
ChargersGameIds = [2021091208, 2021092604, 2021101701, 2021091911, 2021100400, 2021101009, 2021103108]
CardinalsGameIds = [2021091909, 2021101011, 2021102408, 2021102800, 2021091207, 2021092603, 2021100309, 2021101708]
SteelersGameIds = [2021091201, 2021100312, 2021103103, 2021091908, 2021092607, 2021101006, 2021101711]
JaguarsGameIds = [2021091904, 2021092603, 2021101004, 2021101700, 2021091205, 2021093000, 2021103109]
FalconsGameIds = [2021091200, 2021100300, 2021101000, 2021103100, 2021091910, 2021092606, 2021102402]
RaidersGameIds = [2021091300, 2021092610, 2021101010, 2021102407, 2021091908, 2021100400, 2021101709]
BearsGameIds = [2021091901, 2021100302, 2021101703, 2021103102, 2021091213, 2021092601, 2021101010, 2021102409]
GiantsGameIds = [2021091212, 2021092606, 2021101706, 2021102404, 2021091600, 2021100306, 2021101012, 2021110100]
TitansGameIds = [2021091207, 2021092608, 2021101800, 2021102405, 2021091912, 2021100307, 2021101004, 2021103106]
BillsGameIds = [2021091201, 2021092600, 2021100301, 2021103101, 2021091905, 2021101013, 2021101800]
PanthersGameIds = [2021091202, 2021091900, 2021101001, 2021101702, 2021092300, 2021100303, 2021102404, 2021103100]
LionsGameIds = [2021091204, 2021092602, 2021101704, 2021103104, 2021092000, 2021100302, 2021101005, 2021102406]
TexansGameIds = [2021091205, 2021092300, 2021101003, 2021103105, 2021091902, 2021100301, 2021101705, 2021102408]
ColtsGameIds = [2021091206, 2021091903, 2021101705, 2021103106, 2021092608, 2021100304, 2021101100, 2021102410]
CommandersGameIds = [2021091208, 2021091600, 2021101008, 2021101707, 2021092600, 2021100300, 2021102401, 2021103110]
ChiefsGameIds = [2021091209, 2021092604, 2021101013, 2021110100, 2021091913, 2021100308, 2021101707, 2021102405]
EaglesGameIds = [2021091907, 2021100308, 2021101400, 2021091200, 2021092700, 2021101001, 2021102407, 2021103104]
SaintsGameIds = [2021091211, 2021100306, 2021103111, 2021091900, 2021092605, 2021101008, 2021102500]
JetsGameIds = [2021091906, 2021100307, 2021103107, 2021091202, 2021092609, 2021101000, 2021102403]
DolphinsGameIds = [2021091905, 2021100304, 2021102402, 2021091210, 2021092610, 2021101007, 2021101700, 2021103101]
BengalsGameIds = [2021091203, 2021093000, 2021101002, 2021091901, 2021092607, 2021101704, 2021102400, 2021103107]
PackersGameIds = [2021092000, 2021100312, 2021102401, 2021091211, 2021092613, 2021101002, 2021101703, 2021102800]
SanFranciscoGameIds = [2021092613, 2021100310, 2021102410, 2021091204, 2021091907, 2021101011, 2021103102]
CowboysGameIds = [2021092700, 2021100303, 2021101012, 2021090900, 2021091911, 2021101710, 2021103112]

# %% [markdown]
# # Teams

# %% [markdown]
# #### Names

# %%
teamAbbr = {'CLE':{'Name': 'Browns', 'GameIds': BrownsGameIds}, 
            'NE': {'Name': 'Patriots', 'GameIds': PatriotsGameIds}, 
            'TB': {'Name': 'Buccaneers', 'GameIds': BuccaneersGameIds}, 
            'LA': {'Name': 'Rams', 'GameIds': RamsGameIds}, 
            'MIN': {'Name': 'Vikings', 'GameIds': VikingsGameIds}, 
            'DEN': {'Name': 'Broncos', 'GameIds': BroncosGameIds},
            'BAL': {'Name': 'Ravens', 'GameIds': RavensGameIds}, 
            'SEA': {'Name': 'Seahawks', 'GameIds': SeahawksGameIds}, 
            'LAC': {'Name': "Chargers", 'GameIds': ChargersGameIds}, 
            'ARI': {'Name': 'Cardinals', 'GameIds': CardinalsGameIds},
            'PIT': {'Name': 'Steelers', 'GameIds': SteelersGameIds}, 
            'JAX': {'Name': 'Jaguars', 'GameIds': JaguarsGameIds},
            'ATL': {'Name': 'Falcons', 'GameIds': FalconsGameIds}, 
            'LV': {'Name': 'Raiders', 'GameIds': RaidersGameIds}, 
            'CHI': {'Name': 'Bears', 'GameIds': BearsGameIds}, 
            'NYG': {'Name': 'Giants', 'GameIds': GiantsGameIds}, 
            'TEN': {'Name': 'Titans', 'GameIds': TitansGameIds}, 
            'BUF': {'Name': 'Bills', 'GameIds': BillsGameIds}, 
            'CAR': {'Name': 'Panthers', 'GameIds': PanthersGameIds}, 
            'DET': {'Name': 'Lions', 'GameIds': LionsGameIds}, 
            'HOU': {'Name': 'Texans', 'GameIds': TexansGameIds}, 
            'IND': {'Name': 'Colts', 'GameIds': ColtsGameIds}, 
            'WAS': {'Name': 'Commanders', 'GameIds': CommandersGameIds}, 
            'KC': {'Name': 'Chiefs', 'GameIds': ChiefsGameIds}, 
            'PHI': {'Name': 'Eagles', 'GameIds': EaglesGameIds}, 
            'NO': {'Name': 'Saints', 'GameIds': SaintsGameIds}, 
            'NYJ': {'Name': 'Jets', 'GameIds': JetsGameIds}, 
            'MIA': {'Name': 'Dolphins', 'GameIds': DolphinsGameIds}, 
            'CIN': {'Name': 'Bengals', 'GameIds': BengalsGameIds}, 
            'GB': {'Name': 'Packers', 'GameIds': PackersGameIds}, 
            'SF': {'Name': '49ers', 'GameIds': SanFranciscoGameIds}, 
            'DAL': {'Name': 'Cowboys', 'GameIds': CowboysGameIds}}
            
df = pd.DataFrame(teamAbbr)

# %% [markdown]
# # ***SCOUTING***
# ### Schema:
# * gameId: Game identifier, unique (numeric)
# * playId: Play identifier, not unique across games (numeric)
# * nflId: Player identification number, unique across players (numeric)
# * pff_role: The player's role on this play (text)
#  * Possible values:
#  > - Coverage: Defensive player. Player whose initial goal is to play man or zone coverage
#  > - Pass: Offensive player. Player identified as the passer
#  > - Pass block: Offensive player. Anyone fully blocking a defender from the QB, or anyone in a clear pass block stance
#  > - Pass route: Offensive player. Any player not identified as a Pass Blocker or Passer
#  > - Pass rush: Defensive player. Any player whose initial intent is to rush the passer
# * pff_positionLinedUp: Position that the player was aligned at the snap of the ball on this play (text)
# * pff_hit: If player is a defensive player, indicator for whether they are credited with recording a hit on this play (binary)
# * pff_hurry: If player is a defensive player, indicator for whether they are credited with recording a hurry on this play (binary)
# * pff_sack: If player is a defensive player, indicator for whether they are credited with recording a sack on this play (binary)
# * pff_beatenByDefender: If player is a blocking offensive player, indicator for whether they are by a defender but was not charged for yielding a hit, hurry or sack (binary)
# * pff_hitAllowed: If player is a blocking offensive player, indicator for whether they are responsible for a hit on the QB (binary)
# * pff_hurryAllowed: If player is a blocking offensive player, indicator for whether they are responsible for a hurry on the QB (binary)
# * pff_sackAllowed: If player is a blocking offensive player, indicator for whether they are responsible for a sack on the QB (binary)
# * pff_nflIdBlockedPlayer: If player is a blocking offensive player, the nflId of the first defender the offensive player blocked (numeric)
# * pff_blockType: If player is a blocking offensive player, the type of block that the offensive player is executing on the defender (text)
#  * Possible values:
#  > - BH: Backfield Help - A block from a player aligned in the backfield on which the blocker merely helps on a block rather than fully engaging his assignment. Usually seen when a blocker is clearing up a block or picking up a defender when he has broken through or been missed by another blocker
#  > - CH: Chip Block - This is only to be used for players who chip a pass rusher when they release for their route
#  > - CL: Second Level – A block made at the second level, this must be at least two yards across the line of scrimmage
#  > - NB: No Block - If a blocker executes no block on a play but simply runs his path or takes his pass set then we will note him with one all blocking line with this block type
#  > - PA: Play Action Pass Protection - A blocker pass protecting inline on a play action pass selling the play action by stepping in to show a run block before converting to pass protect
#  > - PP: Pass Protection - A standard pass protection block from an inline blocker
#  > - PR: Pocket Roll Block - This block type will be used any time the offense is executing a “rolling pocket” by which the entire offensive line moves with the QB’s rollout to stay in front of him but without ever taking a “conventional” pass set. There will be flexibility here to record the PR – Pocket Roll Block type in the same way as PA & RP block types in that individual matchups & responsibilities won’t always be obvious or necessary, so PR block types can be recorded by multiple blockers on an individual defender on the same play
#  > - PT: Post Block - A post block by an offensive player in pass protection to control a defender for another blocker while clearly demonstrating that he is not, at least initially, trying to fully engage with the block
#  > - PU: Backfield Pickup - A pass protection pick-up by a player aligned in the backfield
#  > - SR: Set & Release - A blocker who sets to pass protect a defender before releasing. This block will cover both players releasing from a set to block for a screen as well as “hold ups” by tight ends before they leak into the flat
#  > - SW: Switch Block - A blocker who passes off (or attempts to pass off) a defender. Most often used on stunts but can also be used for pass offs when pass rushers are slanting across the pocket or interior defenders are working to the edge to replace a dropping edge rusher, with an interior offensive lineman passing them out rather than staying with them
#  > - UP: Pull Pass Protection - A blocker pulling in pass protection from an inline alignment to block a defender in pass protection
# * pff_backFieldBlock:If player is a blocking offensive player, indicator for whether block occured in offensive backfield.

# %%
scouting = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/pffScoutingData.csv")

# %%
# print(scouting.info())

tampa_dal = scouting[scouting['gameId'] == 2021090900]

# %%
tampa_dal_off = tampa_dal[tampa_dal['pff_role'] == 'Pass Block'].copy()
tampa_dal_off.drop(columns=['pff_hurry', 'pff_hit', 'pff_sack'], inplace=True)

# %%
tampa_dal_off.head()
# Out:
#         gameId  playId  nflId    pff_role pff_positionLinedUp  \
# 4   2021090900      97  40151  Pass Block                   C
# 7   2021090900      97  42377  Pass Block                  LT
# 9   2021090900      97  42404  Pass Block                  LG
# 16  2021090900      97  46163  Pass Block                  RG
# 18  2021090900      97  52421  Pass Block                  RT
#
#     pff_beatenByDefender  pff_hitAllowed  pff_hurryAllowed  pff_sackAllowed  \
# 4                    0.0             0.0               0.0              0.0
# 7                    0.0             0.0               1.0              0.0
# 9                    0.0             0.0               0.0              0.0
# 16                   0.0             0.0               1.0              0.0
# 18                   0.0             0.0               1.0              0.0
#
#     pff_nflIdBlockedPlayer pff_blockType  pff_backFieldBlock
# 4                  44955.0            SW                 0.0
# ...

# %% [markdown]
# # ***Players***
# ### Schema:
# * **nflId:** Player identification number, unique across players (numeric int64)
# * **height:** Player height (text object)
# * **weight:** Player weight (numeric int64)
# * **birthDate:** Date of birth (YYYY-MM-DD object)
# * **collegeName:** Player College (text object)
# * **officialPosition:** Official player position (text object)
# * **displayName:** Player Name (text object)

# %%
players = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/players.csv")

# %%
print(players.info())

players.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1679 entries, 0 to 1678
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nflId             1679 non-null   int64
#  1   height            1679 non-null   object
#  2   weight            1679 non-null   int64
#  3   birthDate         1447 non-null   object
#  4   collegeName       1455 non-null   object
#  5   officialPosition  1679 non-null   object
#  6   displayName       1679 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 91.9+ KB
# None
#    nflId height  weight   birthDate collegeName officialPosition  \
# 0  25511    6-4     225  1977-08-03    Michigan               QB
# 1  28963    6-5     240  1982-03-02   Miami, O.               QB
# 2  29550    6-4     328  1982-01-22    Arkansas                T
# 3  29851    6-2     225  1983-12-02  California               QB
# ...

# %% [markdown]
# # ***PLAYS***
# ### Schema:
# * gameId: Game identifier, unique (numeric)
# * playId: Play identifier, not unique across games (numeric)
# * playDescription: Description of play (text)
# * quarter: Game quarter (numeric)
# * down: Down (numeric)
# * yardsToGo: Distance needed for a first down (numeric)
# * possessionTeam: Team abbr of team on offense with possession of ball (text)
# * defensiveTeam: Team abbr of team on defense (text)
# * yardlineSide: 3-letter team code corresponding to line-of-scrimmage (text)
# * yardlineNumber: Yard line at line-of-scrimmage (numeric)
# * gameClock: Time on clock of play (MM:SS)
# * preSnapHomeScore: Home score prior to the play (numeric)
# * preSnapVisitorScore: Visiting team score prior to the play (numeric)
# * passResult: Dropback outcome of the play (text)
#  * C: Complete pass
#  * I: Incomplete pass
#  * S: Quarterback sack
#  * IN: Intercepted pass
#  * R: Scramble
# * penaltyYards: yards gained by offense by penalty (numeric)
# * prePenaltyPlayResult: Net yards gained by the offense, before penalty yardage (numeric)
# * playResult: Net yards gained by the offense, including penalty yardage (numeric)
# * foulName[i]: Name of the i-th penalty committed during the play. i ranges between 1 and 3 (text)
# * foulNFLId[i]: nflId of the player who comitted the i-th penalty during the play. i ranges between 1 and 3 (numeric)
# * absoluteYardlineNumber: Distance from end zone for possession team (numeric)
# * offenseFormation: Formation used by possession team (text)
# * personnelO: Personnel used by offensive team (text)
# * defendersInTheBox: Number of defenders in close proximity to line-of-scrimmage (numeric)
# * personnelD: Personnel used by defensive team (text)
# * dropbackType: Dropback categorization of quarterback (text)
# * pff_playAction: indicator for whether offense executes play action fake on the play. Variable provided by PFF (binary)
# * pff_passCoverage: Coverage scheme of defense. Variable provided by PFF (text)
#  * Possible values:
#  > - Cover-0: A Man to Man coverage across the board with no deep defenders. This coverage is typically accompanied with a blitz
#  > - Cover-1: When a defense plays any form of Man defense across the board with a Defensive Player as a Single High Man concept
#  > - Cover-2: A two deep safety concept where any zone principle is applied
#  > - 2-Man: A two deep safety concept where a man principle is applied
#  > - Cover-3: Any 3 Deep, 4 Under concept
#  > - Quarters: A Quarters concept on both halves of the field. In general it will be a 4 Deep, 3 Under concept where the corners are on #1, safeties on #2, and backside safety rotation dependent on formation
#  > - Cover-6: A Quarters Concept on half the field and a 2 Deep concept on the other half
#  > - Bracket: Recorded in the field and up to the 12 yard line in the red zone – when two offensive players have an in and out bracket by two defenders
#  > - Goal Line: Calls where a Goal Line defense is used.
#  > - Red Zone: Calls that are typically specific to the Red Zone and do not occur in the field often
#  > - Prevent: Special end of half or end of game situations where a Prevent defense is utilized
#  > - Miscellaneous: Coverage concepts that we feel do not comfortably fit into any of our coverage categories
# * pff_passCoverageType: Whether defense's coverage type was man, zone or other. Variable provided by PFF (text)

# %%
plays = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/plays.csv")

# %%
print(plays.info())

plays.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8557 entries, 0 to 8556
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gameId                  8557 non-null   int64
#  1   playId                  8557 non-null   int64
#  2   playDescription         8557 non-null   object
#  3   quarter                 8557 non-null   int64
#  4   down                    8557 non-null   int64
#  5   yardsToGo               8557 non-null   int64
#  6   possessionTeam          8557 non-null   object
#  7   defensiveTeam           8557 non-null   object
#  8   yardlineSide            8432 non-null   object
#  9   yardlineNumber          8557 non-null   int64
#  10  gameClock               8557 non-null   object
#  11  preSnapHomeScore        8557 non-null   int64
#  12  preSnapVisitorScore     8557 non-null   int64
#  13  passResult              8557 non-null   object
# ...

# %% [markdown]
# # ***TRACKING DATA***
# ## Schema:
# * gameId: Game identifier, unique (numeric)
# * playId: Play identifier, not unique across games (numeric)
# * nflId: Player identification number, unique across players. When value is NA, row corresponds to ball. (numeric)
# * frameId: Frame identifier for each play, starting at 1 (numeric)
# * time: Time stamp of play (time, yyyy-mm-dd, hh:mm:ss)
# * jerseyNumber: Jersey number of player (numeric)
# * club: Team abbrevation of corresponding player (text)
# * playDirection: Direction that the offense is moving (left or right)
# * x: Player position along the long axis of the field, 0 - 120 yards. See Figure 1 below. (numeric)
# * y: Player position along the short axis of the field, 0 - 53.3 yards. See Figure 1 below. (numeric)
# * s: Speed in yards/second (numeric)
# * a: Acceleration in yards/second^2 (numeric)
# * dis: Distance traveled from prior time point, in yards (numeric)
# * o: Player orientation (deg), 0 - 360 degrees (numeric)
# * dir: Angle of player motion (deg), 0 - 360 degrees (numeric)
# * event: Tagged play details, including moment of ball snap, pass release, pass catch, tackle, etc (text)

# %% [markdown]
# ## Week 1

# %%
week1 = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/week1.csv")

# %%
print(week1.info())
week1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1118122 entries, 0 to 1118121
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1118122 non-null  int64
#  1   playId         1118122 non-null  int64
#  2   nflId          1069508 non-null  float64
#  3   frameId        1118122 non-null  int64
#  4   time           1118122 non-null  object
#  5   jerseyNumber   1069508 non-null  float64
#  6   team           1118122 non-null  object
#  7   playDirection  1118122 non-null  object
#  8   x              1118122 non-null  float64
#  9   y              1118122 non-null  float64
#  10  s              1118122 non-null  float64
#  11  a              1118122 non-null  float64
#  12  dis            1118122 non-null  float64
#  13  o              1069508 non-null  float64
#  14  dir            1069508 non-null  float64
#  15  event          1118122 non-null  object
# ...

# %% [markdown]
# Buccaneers vs. Cowboys (week 1, plays dataset)
# * 2021090900

# %%
plays.drop(columns=['yardlineSide', 'preSnapHomeScore',
                    'foulName1', 'foulNFLId1',	'foulName2',	
                    'foulNFLId2',	'foulName3', 'foulNFLId3',
                    'penaltyYards', 'prePenaltyPlayResult'], inplace=True)

# %%
TB_DAL_tracking = week1[week1['gameId'] == 2021090900]

# TB_DAL_tracking

# %%
TB_DAL_plays = plays[plays['gameId'] == 2021090900]

TB_DAL_plays.sort_values(by=['possessionTeam', 'quarter', 'gameClock'], ascending=[True, True, False])

TB_DAL_plays
# Out:
#         gameId  playId  \
# 0   2021090900      97
# 1   2021090900     137
# 2   2021090900     187
# 3   2021090900     282
# 4   2021090900     349
# ..         ...     ...
# 92  2021090900    4677
# 93  2021090900    4699
# 94  2021090900    4728
# 95  2021090900    4750
# 96  2021090900    4772
#
#                                                                                            playDescription  \
# 0                                        (13:33) (Shotgun) T.Brady pass incomplete deep right to C.Godwin.
# 1   (13:18) (Shotgun) D.Prescott pass deep left to A.Cooper pushed ob at DAL 30 for 28 yards (A.Winfield).
# 2             (12:23) (Shotgun) D.Prescott pass short middle to D.Schultz to DAL 39 for 5 yards (D.White).
# 3                                                   (9:56) D.Prescott pass incomplete deep left to C.Lamb.
# 4                              (9:46) (Shotgun) D.Prescott pass incomplete short left to C.Lamb [L.David].
# ...

# %% [markdown]
# Falcons vs. Eagles

# %%
ATL_PHI = plays[plays['gameId'] == 2021091200]
ATL_PHI
# Out:
#          gameId  playId  \
# 97   2021091200      56
# 98   2021091200     122
# 99   2021091200     146
# 100  2021091200     176
# 101  2021091200     231
# ..          ...     ...
# 165  2021091200    4274
# 166  2021091200    4298
# 167  2021091200    4317
# 168  2021091200    4346
# 169  2021091200    4367
#
#                                                                                                    playDescription  \
# 97                            (15:00) M.Ryan pass deep middle to C.Ridley to ATL 41 for 16 yards (D.Slay; M.Epps).
# 98          (13:45) (No Huddle) M.Ryan pass short right to C.Patterson to PHI 42 for 1 yard (D.Slay; A.Singleton).
# 99   (13:08) (No Huddle, Shotgun) M.Ryan pass short right to C.Ridley pushed ob at PHI 31 for 11 yards (A.Harris).
# 100                                             (12:50) (No Huddle) M.Ryan pass incomplete short right to K.Pitts.
# ...

# %% [markdown]
# BILLS vs. STEELERS
# * 2021091201

# %%
bills_steelers = plays[plays['gameId'] == 2021091201]
bills_steelers
# Out:
#          gameId  playId  \
# 170  2021091201      63
# 171  2021091201     111
# 172  2021091201     262
# 173  2021091201     345
# 174  2021091201     406
# ..          ...     ...
# 246  2021091201    4156
# 247  2021091201    4180
# 248  2021091201    4209
# 249  2021091201    4233
# 250  2021091201    4266
#
#                                                                                                                                                                             playDescription  \
# 170                                                                                      (14:47) (Shotgun) J.Allen pass short right to C.Beasley to PIT 17 for 7 yards (T.Norwood, D.Bush).
# 171                                                                            (13:40) (No Huddle, Shotgun) J.Allen pass incomplete short left to S.Diggs (C.Heyward). Pass tipped at line.
# ...

# %% [markdown]
# PANTHERS VS JETS
# * 2021091202

# %%
panthers_jets = plays[plays['gameId'] == 2021091202]

# %% [markdown]
# BENGALS VS. VIKINGS
# * 2021091203

# %%
bengals_vikings = plays[plays['gameId'] == 2021091203]
bengals_vikings
# Out:
#          gameId  playId  \
# 323  2021091203     125
# 324  2021091203     149
# 325  2021091203     223
# 326  2021091203     258
# 327  2021091203     280
# ..          ...     ...
# 394  2021091203    4528
# 395  2021091203    4596
# 396  2021091203    4629
# 397  2021091203    4682
# 398  2021091203    4849
#
#                                                                                                                                                                        playDescription  \
# 323                                                                                                  (14:10) K.Cousins pass short middle to T.Conklin to MIN 30 for 6 yards (G.Pratt).
# 324                                                                              (13:33) (Shotgun) K.Cousins pass short left to A.Thielen pushed ob at MIN 42 for 12 yards (M.Hilton).
# ...

# %% [markdown]
# LIONS VS. 49ERS
# * 2021091204

# %%
lions_49ers = plays[plays['gameId'] == 2021091204]

# %% [markdown]
# TEXANS VS. JAGUARS
# * 2021091205

# %%
texans_jags = plays[plays['gameId'] == 2021091205]

# %% [markdown]
# COLTS VS SEAHAWKS
# * 2021091206

# %%
colts_seahawks = plays[plays['gameId'] == 2021091206]

# %% [markdown]
# TITANS VS. CARDINALS
# * 2021091207

# %%
titans_cardinals = plays[plays['gameId'] == 2021091207]

# %% [markdown]
# COMMANDERS VS. CHARGERS
# * 2021091208

# %%
commanders_chargers = plays[plays['gameId'] == 2021091208]

# %% [markdown]
# CHIEFS VS. BROWNS
# * 2021091209

# %%
chiefs_browns = plays[plays['gameId'] == 2021091209]

# %% [markdown]
# PATRIOTS VS. DOLPHINS
# * 2021091210

# %%
pats_dolphins = plays[plays['gameId'] == 2021091210]

# %% [markdown]
# SAINTS VS PACKERS
# * 2021091211

# %%
saints_packers = plays[plays['gameId'] == 2021091211]

# %% [markdown]
# GIANTS VS BRONCOS
# * 2021091212

# %%
giants_broncos = plays[plays['gameId'] == 2021091212]

# %% [markdown]
# RAMS VS. BEARS
# * 2021091213

# %%
rams_bears = plays[plays['gameId'] == 2021091213]

# %% [markdown]
# RAIDERS VS. RAVENS
# * 2021091300

# %%
raiders_ravens = plays[plays['gameId'] == 2021091300]

# %% [markdown]
# ## ***WEEK 2***

# %%
week2 = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/week2.csv")

# %%
print(week2.info())
week2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042774 entries, 0 to 1042773
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1042774 non-null  int64
#  1   playId         1042774 non-null  int64
#  2   nflId          997436 non-null   float64
#  3   frameId        1042774 non-null  int64
#  4   time           1042774 non-null  object
#  5   jerseyNumber   997436 non-null   float64
#  6   team           1042774 non-null  object
#  7   playDirection  1042774 non-null  object
#  8   x              1042774 non-null  float64
#  9   y              1042774 non-null  float64
#  10  s              1042774 non-null  float64
#  11  a              1042774 non-null  float64
#  12  dis            1042774 non-null  float64
#  13  o              997436 non-null   float64
#  14  dir            997436 non-null   float64
#  15  event          1042774 non-null  object
# ...

# %% [markdown]
# ## ***WEEK 3***

# %%
week3 = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/week3.csv")

# %%
print(week3.info())
week3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121825 entries, 0 to 1121824
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1121825 non-null  int64
#  1   playId         1121825 non-null  int64
#  2   nflId          1073050 non-null  float64
#  3   frameId        1121825 non-null  int64
#  4   time           1121825 non-null  object
#  5   jerseyNumber   1073050 non-null  float64
#  6   team           1121825 non-null  object
#  7   playDirection  1121825 non-null  object
#  8   x              1121825 non-null  float64
#  9   y              1121825 non-null  float64
#  10  s              1121825 non-null  float64
#  11  a              1121825 non-null  float64
#  12  dis            1121825 non-null  float64
#  13  o              1073050 non-null  float64
#  14  dir            1073050 non-null  float64
#  15  event          1121825 non-null  object
# ...

# %% [markdown]
# ## ***WEEK 4***

# %%
week4 = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/week4.csv")

# %%
print(week4.info())
week4.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074606 entries, 0 to 1074605
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1074606 non-null  int64
#  1   playId         1074606 non-null  int64
#  2   nflId          1027884 non-null  float64
#  3   frameId        1074606 non-null  int64
#  4   time           1074606 non-null  object
#  5   jerseyNumber   1027884 non-null  float64
#  6   team           1074606 non-null  object
#  7   playDirection  1074606 non-null  object
#  8   x              1074606 non-null  float64
#  9   y              1074606 non-null  float64
#  10  s              1074606 non-null  float64
#  11  a              1074606 non-null  float64
#  12  dis            1074606 non-null  float64
#  13  o              1027884 non-null  float64
#  14  dir            1027884 non-null  float64
#  15  event          1074606 non-null  object
# ...

# %% [markdown]
# ## ***WEEK 5***

# %%
week5 = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/week5.csv")

# %%
print(week5.info())
week5.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1097813 entries, 0 to 1097812
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   gameId         1097813 non-null  int64
#  1   playId         1097813 non-null  int64
#  2   nflId          1050082 non-null  float64
#  3   frameId        1097813 non-null  int64
#  4   time           1097813 non-null  object
#  5   jerseyNumber   1050082 non-null  float64
#  6   team           1097813 non-null  object
#  7   playDirection  1097813 non-null  object
#  8   x              1097813 non-null  float64
#  9   y              1097813 non-null  float64
#  10  s              1097813 non-null  float64
#  11  a              1097813 non-null  float64
#  12  dis            1097813 non-null  float64
#  13  o              1050082 non-null  float64
#  14  dir            1050082 non-null  float64
#  15  event          1097813 non-null  object
# ...

# %% [markdown]
# ## ***WEEK 6***

# %%
week6 = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/week6.csv")

# %%
print(week6.info())
week6.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973797 entries, 0 to 973796
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         973797 non-null  int64
#  1   playId         973797 non-null  int64
#  2   nflId          931458 non-null  float64
#  3   frameId        973797 non-null  int64
#  4   time           973797 non-null  object
#  5   jerseyNumber   931458 non-null  float64
#  6   team           973797 non-null  object
#  7   playDirection  973797 non-null  object
#  8   x              973797 non-null  float64
#  9   y              973797 non-null  float64
#  10  s              973797 non-null  float64
#  11  a              973797 non-null  float64
#  12  dis            973797 non-null  float64
#  13  o              931458 non-null  float64
#  14  dir            931458 non-null  float64
#  15  event          973797 non-null  object
# dtypes: float64(9), int64(3), object(4)
# ...

# %% [markdown]
# ## ***WEEK 7***

# %%
week7 = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/week7.csv")

# %%
print(week7.info())
week7.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 906292 entries, 0 to 906291
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         906292 non-null  int64
#  1   playId         906292 non-null  int64
#  2   nflId          866888 non-null  float64
#  3   frameId        906292 non-null  int64
#  4   time           906292 non-null  object
#  5   jerseyNumber   866888 non-null  float64
#  6   team           906292 non-null  object
#  7   playDirection  906292 non-null  object
#  8   x              906292 non-null  float64
#  9   y              906292 non-null  float64
#  10  s              906292 non-null  float64
#  11  a              906292 non-null  float64
#  12  dis            906292 non-null  float64
#  13  o              866888 non-null  float64
#  14  dir            866888 non-null  float64
#  15  event          906292 non-null  object
# dtypes: float64(9), int64(3), object(4)
# ...

# %% [markdown]
# ## ***WEEK 8***

# %%
week8 = pd.read_csv("/content/drive/MyDrive/KAGGLE_NFL_COMPETITION/nfl-big-data-bowl-2023/week8.csv")

# %%
print(week8.info())
week8.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978949 entries, 0 to 978948
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         978949 non-null  int64
#  1   playId         978949 non-null  int64
#  2   nflId          936386 non-null  float64
#  3   frameId        978949 non-null  int64
#  4   time           978949 non-null  object
#  5   jerseyNumber   936386 non-null  float64
#  6   team           978949 non-null  object
#  7   playDirection  978949 non-null  object
#  8   x              978949 non-null  float64
#  9   y              978949 non-null  float64
#  10  s              978949 non-null  float64
#  11  a              978949 non-null  float64
#  12  dis            978949 non-null  float64
#  13  o              936386 non-null  float64
#  14  dir            936386 non-null  float64
#  15  event          978949 non-null  object
# dtypes: float64(9), int64(3), object(4)
# ...

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
